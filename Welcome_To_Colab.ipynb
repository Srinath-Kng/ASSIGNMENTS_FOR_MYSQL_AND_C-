# %% [markdown]
# <a href="https://colab.research.google.com/github/Srinath-Kng/ASSIGNMENTS_FOR_MYSQL_AND_C-/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Welcome to Colab!</h1>
# </div>
#
# <div class="markdown-google-sans">
#   <h2>Explore the Gemini API</h2>
#   <p>The Gemini API gives you access to Gemini models created by Google DeepMind. Gemini models are built from the ground up to be multimodal, so you can reason seamlessly across text, images, code, and audio.
#   </p>
#   <strong>How to get started</strong>
#     <ol>
#       <li>Go to <a href="https://aistudio.google.com/">Google AI Studio</a> and log in with your Google account.</li>
#       <li><a href="https://aistudio.google.com/app/apikey">Create an API key</a>.</li>
#       <li>Use a quickstart for <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Prompting.ipynb">Python</a>, or call the REST API using <a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/rest/Prompting_REST.ipynb">curl</a>.</li>
#       </ol>
#   <strong>Explore use cases</strong>
#     <ul>
#       <li><a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Market_a_Jet_Backpack.ipynb">Create a marketing campaign</a></li>
#       <li><a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Audio.ipynb">Analyze audio recordings</a></li>
#       <li><a href="https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/System_instructions.ipynb">Use System instructions in chat</a></li>
#     </ul>
#   <p>To learn more, check out the <a href="https://github.com/google-gemini/cookbook">Gemini cookbook</a> or visit the <a href="https://ai.google.dev/docs/">Gemini API documentation</a>.
#   </p>
# </div>

# %%
# !pip install transformers langchain llama-index
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 46.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 50.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 55.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...

# %%
# !pip install transformers
# !pip install langchain
# !pip install llama-index
# Assuming LangChain and LlamaIndex are placeholders, we'll focus on Hugging Face for now

# %%
from transformers import pipeline

# %%
from transformers import pipeline

# Initialize the question generation pipeline
question_generator = pipeline('text2text-generation', model='t5-small')

# Initialize the question answering pipeline
qa_pipeline = pipeline('question-answering')

# Sample text input
text = """
Artificial intelligence (AI) is intelligence demonstrated by machines, in contrast to the natural intelligence displayed by humans and animals. Leading AI textbooks define the field as the study of "intelligent agents": any device that perceives its environment and takes actions that maximize its chance of successfully achieving its goals.
"""

# Define a function to generate questions
def generate_questions(text):
    questions = question_generator(text, max_new_tokens=50, truncation=True)
    return questions

# Define a function to generate answers
def generate_answers(questions, context):
    answers = []
    for question in questions:
        question_text = question['generated_text']
        answer = qa_pipeline(question=question_text, context=context)
        answers.append((question_text, answer['answer']))
    return answers

# Generate questions
questions = generate_questions(text)

# Generate answers for each question
qa_pairs = generate_answers(questions, text)

# Print questions and answers
for question, answer in qa_pairs:
    print(f"Question: {question}")
    print(f"Answer: {answer}\n")
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# ...

# %%
from transformers import pipeline
import random

# Initialize the pipelines
question_generator = pipeline('text2text-generation', model='t5-small')
qa_pipeline = pipeline('question-answering')

# Sample text input
text = """
Artificial intelligence (AI) is intelligence demonstrated by machines, in contrast to the natural intelligence displayed by humans and animals. Leading AI textbooks define the field as the study of "intelligent agents": any device that perceives its environment and takes actions that maximize its chance of successfully achieving its goals.
"""

# Define a function to generate questions
def generate_questions(text):
    questions = question_generator(text, max_new_tokens=50, truncation=True)
    return questions

# Define a function to generate multiple-choice options
def generate_options(question, context):
    # Use the QA model to find the correct answer
    correct_answer = qa_pipeline(question=question, context=context)['answer']

    # Generate distractors using semantic similarity or other techniques
    distractors = [
        "natural agents",
        "artificial devices",
        "intelligent machines"
    ]

    # Randomly select distractors
    options = random.sample(distractors, 2)
    options.append(correct_answer)
    random.shuffle(options)

    return options, correct_answer

# Generate questions
questions = generate_questions(text)

# Generate multiple-choice questions with options
for question in questions:
    question_text = question['generated_text']
    options, correct_answer = generate_options(question_text, text)

    print(f"Question: {question_text}")
    for i, option in enumerate(options, 1):
        print(f"Option {i}: {option}")
    print(f"Correct Answer: {correct_answer}\n")
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Question: : any device that perceives its environment and takes action that maximize its chance of success achieving its goals.
# Option 1: natural agents
# Option 2: intelligent agents
# Option 3: artificial devices
# Correct Answer: intelligent agents

# %%
from transformers import pipeline
import random

# Initialize the pipeline for text summarization or key phrase extraction
summarizer = pipeline('summarization', model='facebook/bart-large-cnn')

# Sample text input
text = """
Artificial intelligence (AI) is intelligence demonstrated by machines, in contrast to the natural intelligence displayed by humans and animals. Leading AI textbooks define the field as the study of "intelligent agents": any device that perceives its environment and takes actions that maximize its chance of successfully achieving its goals.
"""

# Function to generate fill-in-the-blank questions
def generate_fill_in_the_blank(text):
    # Summarize or extract key phrases
    summary = summarizer(text, max_length=50, min_length=25, do_sample=False)[0]['summary_text']

    # Split the summary into words
    words = summary.split()

    # Randomly select a word to replace with a blank
    if len(words) > 5:  # Ensure there's enough context
        blank_index = random.randint(0, len(words) - 1)
        answer = words[blank_index]
        words[blank_index] = "______"
        question = " ".join(words)
    else:
        question = summary
        answer = "N/A"

    return question, answer

# Generate fill-in-the-blank question
question, answer = generate_fill_in_the_blank(text)

# Print the fill-in-the-blank question and answer
print(f"Fill-in-the-Blank Question: {question}")
print(f"Answer: {answer}")
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Fill-in-the-Blank Question: Artificial intelligence (AI) is intelligence demonstrated by machines, in contrast to the natural intelligence displayed by humans and animals. Leading AI textbooks define the field as the study of ______ agents"
# Answer: "intelligent

# %%
from transformers import pipeline
import random

# Sample text input
text = """
Artificial intelligence (AI) is intelligence demonstrated by machines, in contrast to the natural intelligence displayed by humans and animals. Leading AI textbooks define the field as the study of "intelligent agents": any device that perceives its environment and takes actions that maximize its chance of successfully achieving its goals.
"""

# Function to generate true or false questions
def generate_true_false_questions(text):
    # Split the text into sentences
    sentences = text.strip().split('.')

    # Create a list to store true/false questions
    true_false_questions = []

    # Iterate over each sentence
    for sentence in sentences:
        sentence = sentence.strip()
        if sentence:
            # Randomly decide to alter the statement to create a false version
            is_true = random.choice([True, False])
            if not is_true:
                # Alter the statement to make it false
                altered_sentence = sentence.replace("machines", "humans")
                true_false_questions.append((altered_sentence, False))
            else:
                true_false_questions.append((sentence, True))

    return true_false_questions

# Generate true or false questions
questions = generate_true_false_questions(text)

# Print the true or false questions and answers
for i, (question, is_true) in enumerate(questions, 1):
    print(f"Question {i}: {question}?")
    print(f"Answer: {'True' if is_true else 'False'}\n")
# Out:
# Question 1: Artificial intelligence (AI) is intelligence demonstrated by humans, in contrast to the natural intelligence displayed by humans and animals?
# Answer: False
#
# Question 2: Leading AI textbooks define the field as the study of "intelligent agents": any device that perceives its environment and takes actions that maximize its chance of successfully achieving its goals?
# Answer: True

# %%
from transformers import pipeline
import PyPDF2

# Initialize the question generation pipeline with GPU
question_generator = pipeline('text2text-generation', model='t5-small', device=0)

# Initialize the question answering pipeline with GPU
qa_pipeline = pipeline('question-answering', model='distilbert-base-cased-distilled-squad', device=0)

# Function to extract text from a PDF file
def extract_text_from_pdf(pdf_path):
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        text = ''
        for page in reader.pages:
            text += page.extract_text()
    return text

# Function to split text into smaller chunks
def split_text(text, max_length=512):
    sentences = text.split('. ')
    chunks = []
    current_chunk = ''
    for sentence in sentences:
        if len(current_chunk) + len(sentence) > max_length:
            chunks.append(current_chunk)
            current_chunk = sentence
        else:
            current_chunk += ' ' + sentence
    if current_chunk:
        chunks.append(current_chunk)
    return chunks

# Define a function to generate questions
def generate_questions(text):
    questions = question_generator(text, max_new_tokens=100, truncation=True)
    return questions

# Define a function to generate answers
def generate_answers(questions, context):
    answers = []
    for question in questions:
        question_text = question['generated_text']
        answer = qa_pipeline(question=question_text, context=context, max_answer_len=30, doc_stride=50)
        answers.append((question_text, answer['answer']))
    return answers

# Extract text from the PDF file
pdf_path = '/content/Automated Question Builder Application.pdf'  # Replace with your PDF file path
text = extract_text_from_pdf(pdf_path)

# Split text into smaller chunks
text_chunks = split_text(text)

# Generate questions and answers for each chunk
qa_pairs = []
for chunk in text_chunks:
    questions = generate_questions(chunk)
    qa_pairs.extend(generate_answers(questions, chunk))

# Print questions and answers
for question, answer in qa_pairs:
    print(f"Question: {question}")
    print(f"Answer: {answer}\n")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-29-8e862778978c> in <cell line: 57>()
#      57 for chunk in text_chunks:
#      58     questions = generate_questions(chunk)
# ---> 59     qa_pairs.extend(generate_answers(questions, chunk))
#      60
#      61 # Print questions and answers
#
# <ipython-input-29-8e862778978c> in generate_answers(questions, context)
#      42     for question in questions:
#      43         question_text = question['generated_text']
# ---> 44         answer = qa_pipeline(question=question_text, context=context, max_answer_len=30, doc_stride=50)
#      45         answers.append((question_text, answer['answer']))
#      46     return answers
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/question_answering.py in __call__(self, *args, **kwargs)
#     396         examples = self._args_parser(*args, **kwargs)
# ...
